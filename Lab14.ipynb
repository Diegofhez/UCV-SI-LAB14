# %% [markdown]
# <a href="https://colab.research.google.com/github/Diegofhez/UCV-SI-LAB14/blob/main/Lab14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-fuzzy

import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt


x_universe = np.linspace(0, 100, 1000)


bajo = fuzz.trimf(x_universe, [0, 0, 50])
medio = fuzz.trimf(x_universe, [0, 50, 100])
alto = fuzz.trimf(x_universe, [50, 100, 100])


fig, ax = plt.subplots()
ax.plot(x_universe, bajo, 'b', linewidth=1.5, label='Bajo')
ax.plot(x_universe, medio, 'g', linewidth=1.5, label='Medio')
ax.plot(x_universe, alto, 'r', linewidth=1.5, label='Alto')
ax.set_title('Funciones de pertenencia')
ax.legend()

plt.show()
# Out:
# Requirement already satisfied: scikit-fuzzy in /usr/local/lib/python3.11/dist-packages (0.5.0)
